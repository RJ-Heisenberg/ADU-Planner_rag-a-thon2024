# %%
from bs4 import BeautifulSoup
import requests


URL_TEMPLATE = 'https://adubuildingplans.com/properties/construction/adu-construction-plan-ld-{id}/'


def format_key(key: str) -> str:
    key = key.lower().split()
    key = ''.join(key[:1] + [s.capitalize() for s in key[1:]])
    return key


def format_value(val: str) -> dict:
    lines = val.splitlines()
    lines = [line.split(':', 1) for line in lines]
    lines = [tuple(s.strip() for s in line) for line in lines]
    if any(len(line) == 1 for line in lines):
        return sum(map(list, lines), [])
    else:
        return {format_key(key): val for key, val in lines}


def format_properties(rows):
    properties = {}
    for row in rows:
        td = row.find_all('td')
        key = format_key(td[0].text)
        val = format_value(td[1].text)
        properties[key] = val
    return properties


def get_properties(url):
    response = requests.get(url)
    if response.status_code != 200:
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    rows = soup.find('tbody').find_all('tr')
    return format_properties(rows)


properties = {}
for id in range(1901, 1916):
    result = get_properties(URL_TEMPLATE.format(id=id))
    if result is None:
        print(f'WARNING: could not get properties of {id}')
    properties[id] = result

properties
# Out:
# {1901: {'dimension': {'depth': '20’04″‘', 'height': '12’8″', 'width': '18’5″'},
#   'area': {'firstFloor': '375 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Siding', 'framing': '2″x6″'},
#   'loftFeatures': ['Closet'],
#   'kitchenFeatures': ['Small Kitchen'],
#   'rooms': {'loft': 'width 9′ 3″ x depth 19′ 4″',
#    'closet': 'width 2′ 4″ x depth 8′ 7″',
#    'bathroom': 'width 5′ 1″ x depth 8′ 7″',
#    'kitchen': 'width 8′ 2 x depth 10′ 5″'}},
#  1902: {'dimension': {'depth': '19″03′', 'height': '12’5″', 'width': '20’01”'},
#   'area': {'firstFloor': '403 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Siding', 'framing': '2″x6″'},
#   'loftFeatures': ['Closet'],
#   'kitchenFeatures': ['Small Kitchen'],
#   'rooms': {'loft': 'width 8′ 8″ x depth 19′ 3″',
#    'closet': 'width 2′ 4″ x depth 7′ 1″',
#    'bathroom': 'width 7′ 6″ x depth 7′ 1″',
#    'kitchen': 'width 10′ 7 x depth 11′ 10″'}},
#  1903: {'dimension': {'depth': '25’03″‘', 'height': '13’3″', 'width': '38’6″'},
#   'area': {'firstFloor': '972 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Siding\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Exterior Wall Finish : Stone Panel Gray Rock',
#    'framing': '2″x6″'},
#   'loftFeatures': ['Entry , Porch, Laundry'],
#   'kitchenFeatures': ['Full appliences'],
#   'rooms': {'livingRoom': 'width 12′ 0″ x depth 9′ 9″',
#    'diningRoom': 'width 12′ 0″ x depth 9′ 9″',
#    'bathroom': 'width 5′ 0″ x depth 9′ 0″',
#    'kitchen': 'width 7′ 3″ x depth 11′ 5″',
#    'bedroom1': 'width 12′ 9″ x depth 9′ 5″',
#    'bedroom2': 'width 12′ 9″ x depth 9′ 5″',
#    'porch2': 'width 22′ 4″ x depth 5′ 0″'}},
#  1904: {'dimension': {'depth': '20’00″‘',
#    'height': '12’05”',
#    'width': '29’00”'},
#   'area': {'firstFloor': '580 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'stuccu', 'framing': '2″x6″'},
#   'additionalRoomFeatures': ['Den'],
#   'garageFeatures': ['no'],
#   'rooms': {'bedroom1': 'width 12’08” x depth 9’04”',
#    'den': 'width 8’11” x depth 9′ 05″',
#    'livingRoom': 'width 12’05” x depth 12′ 09″',
#    'kitchen': 'width 9’05” x depth 6′ 05″'}},
#  1905: {'dimension': {'depth': '26’07″‘',
#    'height': '13’01”',
#    'width': '21’04”'},
#   'area': {'firstFloor': '421 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'stuccu / wood',
#    'framing': '2″x6″'},
#   'bedroomFeatures': ['Split Bedrooms', 'Walk In Closet'],
#   'additionalRoomFeatures': ['Entry Porch'],
#   'garageFeatures': ['no'],
#   'rooms': {'bedroom1': 'width 10’00” x depth 10’01”',
#    'livingRoom': 'width 10’03” x depth 10′ 11″',
#    'kitchen': 'width 10’03” x depth 8′ 00″'}},
#  1906: {'dimension': {'depth': '14′', 'height': '20′', 'width': '36′'},
#   'area': {'firstFloor': '504 sq/ft',
#    'secondFloor': '168 sq/ft',
#    'total': '672 sq/ ft'},
#   'ceiling': {'mainCeiling': '18′'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '3:12',
#    'roofType': 'Metallic Roof'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'metallic / wood',
#    'framing': '2″x6″'},
#   'loft': ['168 sq. ft.'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'additionalRoomFeatures': ['Laundry / Exterior deck'],
#   'rooms': {'loft': 'width 11’6″ x depth 13’1″',
#    'greatRoom': 'width 13’10” x depth 13’01”',
#    'kitchen': 'width 13’6″ x depth 10’0″'}},
#  1907: {'dimension': {'depth': '18’00″‘',
#    'height': '11’10”',
#    'width': '17’00”'},
#   'area': {'firstFloor': '306 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'stuccu / clay brick',
#    'framing': '2″x6″'},
#   'kitchenFeatures': ['Full Kitchen'],
#   'rooms': {'livingSpace': 'width 8’2″ x depth 14’7″',
#    'kitchen': 'width 7’10” x depth 10’00”'}},
#  1908: {'dimension': {'depth': '21’00″‘',
#    'height': '13’05”',
#    'width': '20’00”'},
#   'area': {'firstFloor': '420 sq/ft'},
#   'ceiling': {'mainCeiling': 'Vaulted Celing'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '2:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'stuccu / wood',
#    'framing': '2″x6″'},
#   'kitchenFeatures': ['Full kitchen'],
#   'rooms': {'livingSpace': 'width 11’02” x depth 19′',
#    'den': 'width 10′ x depth 10′',
#    'kitchen': 'width 8’10” x depth 11′ 8″'}},
#  1909: {'dimension': {'depth': '20’00″‘', 'height': '12’6″', 'width': '21’0″'},
#   'area': {'firstFloor': '420 sq/ft'},
#   'ceiling': {'mainCeiling': '8’6″'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '1:12',
#    'roofType': 'Membrane'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Wood Siding',
#    'framing': '2″x6″'},
#   'kitchenFeatures': ['Full Kitchen'],
#   'rooms': {'livingSpace': 'width 12′ 01″ x depth 10′ 4″',
#    'kitchen': 'width 20′ 00″ x depth 8′ 9″'}},
#  1910: {'dimension': {'depth': '21’00″‘',
#    'height': '13’05”',
#    'width': '20’00”'},
#   'area': {'firstFloor': '420 sq/ft'},
#   'ceiling': {'mainCeiling': 'Vaulted Celing'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '2:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Vertical siding\xa0 / teck\xa0 wood',
#    'framing': '2″x6″'},
#   'kitchenFeatures': ['Full kitchen'],
#   'rooms': {'livingSpace': 'width 11’02” x depth 19′',
#    'den': 'width 10′ x depth 10′',
#    'kitchen': 'width 8’10” x depth 11′ 8″'}},
#  1911: {'dimension': {'depth': '22’04″‘',
#    'height': '21’03”',
#    'width': '20’02”'},
#   'area': {'firstFloor': '409 sq/ft\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Second Floor: 373 sq/ft'},
#   'ceiling': {'1stFloorCeiling': '8’3′\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 2nd floor Ceiling : 8’6′'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '3:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'stuccu', 'framing': '2″x6″'},
#   'bedroomFeatures': ['Laundry room', 'Walk In Closet'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'additionalRoomFeatures': ['Balcony'],
#   'rooms': {'bedroom1': 'width 13’04” x depth 12’9″',
#    'diningRoom': 'width 7’11” x depth 8′ 3″',
#    'livingRoom': 'width 16′ 9″ x depth 10′',
#    'kitchen': 'width 11’05” x depth 8′ 3″'}},
#  1912: {'dimension': {'depth': '22’04″‘',
#    'height': '21’03”',
#    'width': '20’02”'},
#   'area': {'firstFloor': '409 sq/ft', 'secondFloor': '373 sq/ft'},
#   'ceiling': {'1stFloorCeiling': '8’3′', '2ndFloorCeiling': '8’6′'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '3:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Brick / Siding',
#    'framing': '2″x6″'},
#   'bedroomFeatures': ['Laundry room', 'Walk In Closet'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'additionalRoomFeatures': ['Balcony'],
#   'rooms': {'bedroom1': 'width 13’04” x depth 12’9″',
#    'diningRoom': 'width 7’11” x depth 8′ 3″',
#    'livingRoom': 'width 16′ 9″ x depth 10′',
#    'kitchen': 'width 11’05” x depth 8′ 3″'}},
#  1913: {'dimension': {'depth': '22’04″‘',
#    'height': '21’03”',
#    'width': '20’02”'},
#   'area': {'firstFloor': '409 sq/ft Second Floor: 373 sq/ft'},
#   'ceiling': {'1stFloorCeiling': '8’3′ 2nd floor Ceiling : 8’6′'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '3:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'eteriorWallFinish': 'Stuccu / Siding',
#    'framing': '2″x6″'},
#   'bedroomFeatures': ['Laundry room', 'Walk In Closet'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'additionalRoomFeatures': ['Balcony'],
#   'rooms': ['Bedroom 1',
#    '',
#    'width 13’04” x depth 12’9″',
#    'Dining Room',
#    '',
#    'width 7’11” x depth 8′ 3″',
#    'Living Room',
#    '',
#    'width 16′ 9″ x depth 10′',
#    'Kitchen',
#    '',
#    'width 11’05” x depth 8′ 3″']},
#  1914: {'dimension': {'depth': '22’06″‘',
#    'height': '13’01”',
#    'width': '20’02”'},
#   'area': {'firstFloor': '550 sq/ft'},
#   'ceiling': {'1stFloorCeiling': '8’6′'},
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Siding', 'framing': '2″x6″'},
#   'bedroomFeatures': ['Walk In Closet'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'additionalRoomFeatures': ['–'],
#   'rooms': ['Bedroom 1',
#    '',
#    'width 11’05” x depth 11’11”',
#    'Walk in Closet',
#    '',
#    'width 5’11” x depth 9′ 3″',
#    'Bathroom',
#    '',
#    'width 5’01” x depth 9′ 3″',
#    'Living Room',
#    '',
#    'width 11′ 9″ x depth 11’08”',
#    'Kitchen',
#    '',
#    'width 11’09” x depth 9′ 10″']},
#  1915: {'dimension': {'depth': '20’00″‘',
#    'height': '12’06”',
#    'width': '31’06”'},
#   'area': {'firstFloor': '632 sq/ft'},
#   'ceiling': ['Vaulted'],
#   'roof': {'roofFraming': 'Conventional',
#    'primaryPitch': '4:12',
#    'roofType': 'Composition shingle'},
#   'exteriorWallFraming': {'exteriorWallFinish': 'Stucco', 'framing': '2″x6″'},
#   'bedroomFeatures': ['Walk In Closet'],
#   'kitchenFeatures': ['Full Kitchen'],
#   'rooms': ['Bedroom 1',
#    '',
#    'width 10′” x depth 8’11”',
#    'Bedroom 2',
#    '',
#    'width 11’01” x depth 9’11”',
#    'Bathroom',
#    '',
#    'width 9′ 9″ x depth 5′ 2″',
#    'Living Room',
#    '',
#    'width 8′ 11″ x depth 13’09”',
#    'Kitchen',
#    '',
#    'width 7’9″ x depth 14′ 4″']}}

# %%
import json

with open("adus.json", "w") as f:
    json.dump(properties, f)
